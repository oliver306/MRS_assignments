# %% [markdown]
# <h3>Task 1: Shot Cut Detection (30 Pt.)</h3><p>
# Evaluate the performance of two different visual-based shot cut detection algorithms, e.g.
# inter-frame difference and color histograms. Compare histograms using the
# Euclidean distance and Histogram intersection. In order to evaluate the
# performance of the implemented approaches download&nbsp;the provided ground truth for the
# videos of the TestSet. Run your shot cut detection approaches on all 5 videos
# of the TestSet and compare the results to the ground truth and compute true,
# false and missed shot boundaries. Additionally, compute recall, precision and
# F1.<br>
# <br>
# Answer the following questions: </p>
#
# <ul>
# <li>What are the strengths and the
# limitations of each approach? Show examples where the methods did not perform well. Why is this so? </li>
# <li>Which similarity measure performs better? Why? </li>
# <li>Add the average shot length per genre to your report. Is there any relationship between (average) shot length and video genre? </li>
# <li>Provide a table with the number of true, false and missed shot boundaries as well as recall, precision and F1. Additionally discuss the results. </li>
# </ul>

# %%
# %run Implementation.ipynb

df1, df2 = detect_and_compare_all("../videos/TestSet", 100, mode = "both")

display(df1)
display(df2)
# Out:
# ../videos/TestSet\01_DevilsAdvocate_01.mp4:
# detected:  [   1  270  316  382  438  471  507  547  656  881  941  977 1052 1091
#  1140 1162 1300 1369]
# truth:  [   1  270  316  382  438  471  507  547  656  881  941  977 1052 1091
#  1140 1162 1300 1369]
# HISTOGRAM:
# Hits: 18.0
# Misses: 0.0
# Recall: 1.0
# Precision: 1.0
# F1 Measure: 1.0
#
# detected:  [1.]
# truth:  [   1  270  316  382  438  471  507  547  656  881  941  977 1052 1091
#  1140 1162 1300 1369]
# PIXEL DIFFERENCE:
# Hits: 1.0
# Misses: 17.0
# Recall: 0.05555555555555555
# Precision: 0.05555555555555555
# F1 Measure: 0.05555555555555555
#
#
#
# ../videos/TestSet\01_PulpFiction_01.mp4:
# detected:  [   1 1184 1391]
# truth:  [   1 1184 1391]
# HISTOGRAM:
# Hits: 3.0
# Misses: 0.0
# Recall: 1.0
# Precision: 1.0
# F1 Measure: 1.0
#
# detected:  [1.]
# truth:  [   1 1184 1391]
# PIXEL DIFFERENCE:
# Hits: 1.0
# Misses: 2.0
# Recall: 0.3333333333333333
# Precision: 0.3333333333333333
# F1 Measure: 0.3333333333333333
#
# ...
