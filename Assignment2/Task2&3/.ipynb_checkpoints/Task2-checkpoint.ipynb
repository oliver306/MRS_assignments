# %% [markdown]
# <h2>Task 2 - Feature extraction (30 pts)</h2><p>The goal of
# this task is to define a set of expedient features, extract them from the audio
# signals and combine the results. There are some good papers which deal exactly
# with the proper selection and combination of musical features: (you may use
# other sources as well)</p>
#
# <ul type="disc">
#  </ul><div style="margin-left: 30px;" class="editor-indent"><ul><li>"Manipulation, Analysis
#      and Retrieval Systems for Audio Signals" by Tzanetakis (<span lang="EN-GB"><a href="http://www-2.cs.cmu.edu/%7Egtzan/work/pubs/thesis02gtzan.pdf" title="http://www-2.cs.cmu.edu/~gtzan/work/pubs/thesis02gtzan.pdf"><span lang="EN-US">http://www-2.cs.cmu.edu/~gtzan/work/pubs/thesis02gtzan.pdf</span></a></span>)</li><li>"Automatic Musical Genre
#      Classification Of Audio Signals" by Tzanetakis et al. (<span lang="EN-GB"><a href="http://ismir2001.ismir.net/pdf/tzanetakis.pdf" title="http://ismir2001.ismir.net/pdf/tzanetakis.pdf"><span lang="EN-US">http://ismir2001.ismir.net/pdf/tzanetakis.pdf</span></a></span>)</li><li>"Evaluation of Feature
#      Extractors and Psycho-acoustic Transformations for Music Genre
#      Classification." by Thomas Lidy and Andreas Rauber (<span lang="EN-GB"><a href="http://ismir2005.ismir.net/proceedings/1033.pdf" title="http://ismir2005.ismir.net/proceedings/1033.pdf"><span lang="EN-US">http://ismir2005.ismir.net/proceedings/1033.pdf</span></a></span>)</li></ul></div><ul type="disc">
# </ul>
#
# <p>Determine your own set of features that you want to use. You may also define custom
# features (that do not occur in any publications) as well, but make sure that
# you are able to interpret, calculate and explain their functionality. The
# following requirements must be fulfilled:</p>
#
# <ul type="disc">
#  </ul><div style="margin-left: 30px;" class="editor-indent"><ul><li>Use (at least) 5 features and
#      combine them to a feature vector.</li><li>Make use of features of the
#      time-domain AND the frequency-domain</li></ul></div><ul type="disc">
# </ul>
#
# <p>You may use
# the following suggestions for your selection. Consider sums, median, means,
# standard deviations if applicable.</p>
#
# <ul type="disc">
#  </ul><div style="margin-left: 30px;" class="editor-indent"><ul><li>Rolloff</li><li>Centroid</li><li>Tempo / Beats per minute</li><li>Pitch</li><li>Energy</li><li>Zero crossing rate (ZCR)</li><li>Rhythm patterns</li><li>Statistical Spectrum
#      Descriptors</li><li>Autocorrelation</li><li>Spectral Peaks</li><li>MFCC</li><li>...</li></ul></div><ul type="disc">
# </ul>
#
# <p>We recommend
# to use LibROSA for feature extraction.</p>
#
# <p>Example
# vector:</p>
#
# <p>[(zcr); (centroid mean); (centroid std); (bpm); (flux mean)]</p>
#
# <p>The results of this task is the implementation of a feature-extraction function, a detailed description and reasons for their choice and - as a final result - the complete feature-vector representation for each of the provided audio tracks (ie. dataframe of <i>n</i> x <i>m</i> dimensions, where <i>n</i> states the number of files, <i>m</i> indicates the number of features).</p>

# %%
# %run Implementation.ipynb

#relies on having run task1 and having the processed audio files stored in a directory (dir parameter)
#extracts all features from these files, outputs results and plots them
#displays feature matrix, genre mean and genre standard deviation
processAndDisplayAudioDirectoryFeatures(dir="../videos/processed", plot=True, showDataframes=True)
# Out:
# COMPLETE FEATURE MATRIX             Centroid Mean  Centroid Std  \
# 01_DevilsAdvocate_02_processed.wav     757.671073    489.233834
# 01_DevilsAdvocate_03_processed.wav    1439.161942    586.242191
# 01_DevilsAdvocate_04_processed.wav    1642.637875    521.747656
# 01_DevilsAdvocate_05_processed.wav    1314.814565    344.946643
# 01_PulpFiction_02_processed.wav       1448.894670    330.496897
# 01_PulpFiction_03_processed.wav       1468.940072    330.439735
# 01_PulpFiction_04_processed.wav       1449.168362    258.500642
# 01_PulpFiction_05_processed.wav       1329.248550    370.702723
# 02_HowSheMove_02_processed.wav        1399.557883    392.097325
# 02_HowSheMove_03_processed.wav        1234.928995    280.871642
# 02_HowSheMove_04_processed.wav        1318.583605    430.446307
# 02_HowSheMove_05_processed.wav        1141.041666    369.069240
# 02_LastDance_02_processed.wav         1810.298003    322.664013
# 02_LastDance_03_processed.wav         1282.422967    425.781010
# 02_LastDance_04_processed.wav         1261.213498    372.879743
# 02_LastDance_05_processed.wav         1584.730782    416.072176
# 03_ArcticTale_02_processed.wav        1081.926322    362.589767
# 03_ArcticTale_03_processed.wav        1125.412377    280.669501
# 03_ArcticTale_04_processed.wav        1432.828073    242.129003
# 03_ArcticTale_05_processed.wav        1270.326318    268.320150
#
# COMPLETE FEATURE MATRIX             Roll-off mean  Roll-off Std       Tempo  \
# 01_DevilsAdvocate_02_processed.wav    1535.989359   1068.173066  117.453835
# 01_DevilsAdvocate_03_processed.wav    2928.757103    837.742536  117.453835
# 01_DevilsAdvocate_04_processed.wav    3105.689921    721.921725  117.453835
# 01_DevilsAdvocate_05_processed.wav    2664.163498    669.294711  117.453835
# 01_PulpFiction_02_processed.wav       2986.112364    658.107672  129.199219
# 01_PulpFiction_03_processed.wav       2991.957804    573.328511  143.554688
# 01_PulpFiction_04_processed.wav       2968.163864    500.182260  161.499023
# 01_PulpFiction_05_processed.wav       2773.590640    787.830960  107.666016
# 02_HowSheMove_02_processed.wav        2848.415607    571.118820  129.199219
# 02_HowSheMove_03_processed.wav        2479.749017    541.234780  107.666016
# 02_HowSheMove_04_processed.wav        2785.793621    782.728028  107.666016
# 02_HowSheMove_05_processed.wav        2481.772438    802.481490  117.453835
# 02_LastDance_02_processed.wav         3618.152677    450.050220  107.666016
# 02_LastDance_03_processed.wav         2814.017439    907.345921  129.199219
# 02_LastDance_04_processed.wav         2552.908616    724.805332  117.453835
# 02_LastDance_05_processed.wav         3006.779576    705.114164  117.453835
# 03_ArcticTale_02_processed.wav        2214.422650    813.574945  129.199219
# 03_ArcticTale_03_processed.wav        2401.281059    730.167853   86.132812
# 03_ArcticTale_04_processed.wav        2881.110936    512.848713  129.199219
# 03_ArcticTale_05_processed.wav        2662.323267    640.303693  129.199219
#
# COMPLETE FEATURE MATRIX             Zero Crossing Mean  Zero Crossing Std  \
# 01_DevilsAdvocate_02_processed.wav            0.066199           0.069195
# 01_DevilsAdvocate_03_processed.wav            0.156739           0.100159
# 01_DevilsAdvocate_04_processed.wav            0.194855           0.100014
# 01_DevilsAdvocate_05_processed.wav            0.142865           0.053300
# 01_PulpFiction_02_processed.wav               0.172602           0.055029
# 01_PulpFiction_03_processed.wav               0.173744           0.064796
# 01_PulpFiction_04_processed.wav               0.164392           0.046774
# 01_PulpFiction_05_processed.wav               0.142845           0.058202
# 02_HowSheMove_02_processed.wav                0.151702           0.075253
# 02_HowSheMove_03_processed.wav                0.133341           0.053266
# 02_HowSheMove_04_processed.wav                0.102031           0.062939
# 02_HowSheMove_05_processed.wav                0.107016           0.054825
# 02_LastDance_02_processed.wav                 0.227945           0.075815
# 02_LastDance_03_processed.wav                 0.116563           0.058743
# 02_LastDance_04_processed.wav                 0.129632           0.052583
# 02_LastDance_05_processed.wav                 0.206408           0.087817
# 03_ArcticTale_02_processed.wav                0.111737           0.053880
# 03_ArcticTale_03_processed.wav                0.101464           0.034039
# 03_ArcticTale_04_processed.wav                0.171781           0.048979
# 03_ArcticTale_05_processed.wav                0.140534           0.046476
#
# COMPLETE FEATURE MATRIX             Energy Means  Energy Std  Flux Mean  \
# 01_DevilsAdvocate_02_processed.wav      0.226797    0.507005   0.873371
# 01_DevilsAdvocate_03_processed.wav      0.136213    0.347637   1.609600
# 01_DevilsAdvocate_04_processed.wav      0.185677    0.570849   1.622195
# 01_DevilsAdvocate_05_processed.wav      0.043772    0.101901   1.211637
# 01_PulpFiction_02_processed.wav         3.386305    3.338163   1.121525
# 01_PulpFiction_03_processed.wav         1.887055    2.934776   1.012929
# 01_PulpFiction_04_processed.wav         2.601114    1.863185   1.162990
# 01_PulpFiction_05_processed.wav         1.301486    1.881650   1.350527
# 02_HowSheMove_02_processed.wav          8.763482   16.889363   1.341621
# 02_HowSheMove_03_processed.wav          4.516225    7.590366   1.138209
# 02_HowSheMove_04_processed.wav          2.183219    5.035853   1.594485
# 02_HowSheMove_05_processed.wav          1.694550    4.896759   1.381809
# 02_LastDance_02_processed.wav           0.233618    0.244029   1.182514
# 02_LastDance_03_processed.wav           0.065926    0.064176   1.491309
# 02_LastDance_04_processed.wav           0.170821    0.228144   1.148700
# 02_LastDance_05_processed.wav           0.066490    0.102516   1.390799
# 03_ArcticTale_02_processed.wav          0.141981    0.290604   1.141592
# 03_ArcticTale_03_processed.wav          0.542130    0.511117   1.230620
# 03_ArcticTale_04_processed.wav          0.263537    0.629841   0.832732
# 03_ArcticTale_05_processed.wav          0.435483    0.452583   0.845122
#
# COMPLETE FEATURE MATRIX             Flux Std
# 01_DevilsAdvocate_02_processed.wav  0.923681
# 01_DevilsAdvocate_03_processed.wav  1.978083
# 01_DevilsAdvocate_04_processed.wav  1.907416
# 01_DevilsAdvocate_05_processed.wav  1.266881
# 01_PulpFiction_02_processed.wav     0.767587
# 01_PulpFiction_03_processed.wav     0.906385
# 01_PulpFiction_04_processed.wav     1.038850
# 01_PulpFiction_05_processed.wav     1.169789
# 02_HowSheMove_02_processed.wav      1.735261
# 02_HowSheMove_03_processed.wav      1.179932
# 02_HowSheMove_04_processed.wav      2.227608
# 02_HowSheMove_05_processed.wav      1.837185
# 02_LastDance_02_processed.wav       0.934762
# 02_LastDance_03_processed.wav       1.623989
# 02_LastDance_04_processed.wav       1.032221
# 02_LastDance_05_processed.wav       1.249356
# 03_ArcticTale_02_processed.wav      1.032037
# 03_ArcticTale_03_processed.wav      1.046141
# 03_ArcticTale_04_processed.wav      0.595595
# 03_ArcticTale_05_processed.wav      0.586943
# MOVIE MEAN MATRIX  Centroid Means Mean  Centroid Stds Mean  \
# DEVILS ADVOCATE            1288.571364          485.542581
# PULP FICTION               1424.062913          322.534999
# HOW SHE MOVE               1273.528037          368.121128
# LAST DANCE                 1484.666312          384.349235
# ARCTIC TALE                1227.623272          288.427105
#
# MOVIE MEAN MATRIX  Roll-off Means Mean  Roll-off Stds Mean       Tempo  \
# DEVILS ADVOCATE            2558.649970          824.283010  117.453835
# PULP FICTION               2929.956168          629.862351  135.479736
# HOW SHE MOVE               2648.932671          674.390779  115.496271
# LAST DANCE                 2997.964577          696.828909  117.943226
# ARCTIC TALE                2539.784478          674.223801  118.432617
#
# MOVIE MEAN MATRIX  Zero Crossing Means Mean  Zero Crossing Stds Mean  \
# DEVILS ADVOCATE                    0.140165                 0.080667
# PULP FICTION                       0.163396                 0.056200
# HOW SHE MOVE                       0.123522                 0.061571
# LAST DANCE                         0.170137                 0.068740
# ARCTIC TALE                        0.131379                 0.045844
#
# MOVIE MEAN MATRIX  Energy Means Mean  Energy Means Std  Flux Means Mean  \
# DEVILS ADVOCATE             0.148115          0.381848         1.329201
# PULP FICTION                2.293990          2.504444         1.161993
# HOW SHE MOVE                4.289369          8.603085         1.364031
# LAST DANCE                  0.134214          0.159716         1.303330
# ARCTIC TALE                 0.345783          0.471036         1.012516
#
# MOVIE MEAN MATRIX  Flux Means Std
# DEVILS ADVOCATE          1.519015
# PULP FICTION             0.970653
# HOW SHE MOVE             1.744996
# LAST DANCE               1.210082
# ARCTIC TALE              0.815179
# MOVIE STD MATRIX  Centroid Means Std  Centroid Stds Std  Roll-off means Std  \
# DEVILS ADVOCATE           328.094667          88.362976          610.982780
# PULP FICTION               55.341265          40.454929           90.702436
# HOW SHE MOVE               96.119783          54.937823          169.624596
# LAST DANCE                227.421650          40.803042          392.626522
# ARCTIC TALE               137.483844          45.022452          253.260253
#
# MOVIE STD MATRIX  Roll-off Stds Std  Tempos Std  Zero Crossing Means Std  \
# DEVILS ADVOCATE          153.429726    0.000000                 0.046754
# PULP FICTION             106.963639   19.718368                 0.012401
# HOW SHE MOVE             118.890504    8.863248                 0.020155
# LAST DANCE               162.840765    7.628850                 0.047875
# ARCTIC TALE              111.513420   18.648301                 0.027372
#
# MOVIE STD MATRIX  Zero Crossing Stds Std  Energy Means Std  Energy Stds Std  \
# DEVILS ADVOCATE                 0.020216          0.068247         0.180919
# PULP FICTION                    0.006483          0.780727         0.647950
# HOW SHE MOVE                    0.008712          2.794553         4.902806
# LAST DANCE                      0.013919          0.071538         0.077767
# ARCTIC TALE                     0.007317          0.154027         0.122190
#
# MOVIE STD MATRIX  Flux Means Std  Flux Stds Std
# DEVILS ADVOCATE         0.310673       0.441473
# PULP FICTION            0.121865       0.149726
# HOW SHE MOVE            0.161959       0.374435
# LAST DANCE              0.142736       0.264716
# ARCTIC TALE             0.176475       0.223986
# GENRE MEAN MATRIX  Centroid Means Mean  Centroid Stds Mean  \
# THRILLER                   1356.317139          404.038790
# DANCE                      1379.097175          376.235182
# DOCUMENTARY                1227.623272          288.427105
#
# GENRE MEAN MATRIX  Roll-off Means Mean  Roll-off Stds Mean       Tempo  \
# THRILLER                   2744.303069          727.072680  126.466786
# DANCE                      2823.448624          685.609844  116.719749
# DOCUMENTARY                2539.784478          674.223801  118.432617
#
# GENRE MEAN MATRIX  Zero Crossing Means Mean  Zero Crossing Stds Mean  \
# THRILLER                           0.151780                 0.068434
# DANCE                              0.146830                 0.065155
# DOCUMENTARY                        0.131379                 0.045844
#
# GENRE MEAN MATRIX  Energy Means Mean  Energy Means Std  Flux Means Mean  \
# THRILLER                    1.221052          1.443146         1.245597
# DANCE                       2.211792          4.381401         1.333681
# DOCUMENTARY                 0.345783          0.471036         1.012516
#
# GENRE MEAN MATRIX  Flux Means Std
# THRILLER                 1.244834
# DANCE                    1.477539
# DOCUMENTARY              0.815179
# GENRE STD MATRIX  Centroid Means Std  Centroid Stds Std  Roll-off means Std  \
# THRILLER                  244.834379         106.607581          474.584574
# DANCE                     204.021206          49.064897          349.170248
# DOCUMENTARY               137.483844          45.022452          253.260253
#
# GENRE STD MATRIX  Roll-off Stds Std  Tempos Std  Zero Crossing Means Std  \
# THRILLER                 164.136524   16.602418                 0.036122
# DANCE                    143.010142    8.359136                 0.043501
# DOCUMENTARY              111.513420   18.648301                 0.027372
#
# GENRE STD MATRIX  Zero Crossing Stds Std  Energy Means Std  Energy Stds Std  \
# THRILLER                        0.019366          1.207597         1.163030
# DANCE                           0.012152          2.867691         5.463002
# DOCUMENTARY                     0.007317          0.154027         0.122190
#
# GENRE STD MATRIX  Flux Means Std  Flux Stds Std
# THRILLER                0.250348       0.428758
# DANCE                   0.155638       0.420323
# DOCUMENTARY             0.176475       0.223986

# %% [markdown]
# <p>Answer the
# following questions:</p>
#
# <ul type="disc">
#  <li>What are audio features (as
#      opposed to annotations)?</li>
#  <li>How are features that are
#      extracted from the frequency domain being gathered? Outline typical
#      processing steps.</li>
#  <li>Fourier-transformed audio
#      signals naturally loose their temporal information. How can this be
#      circumvented?</li>
# </ul>
#
# </ul>
# <p></p>
# <hr>

# %% [markdown]
# <h2>Task 3 - Analysis and Visualization (20 pts)</h2><p>Evaluate
# your features using the results of Task 2 and the ground-truth (cp. Necessary preparations)
# with special focus on the association of similar sounding signals to their
# pre-defined genre class. Provide a detailed protocol including figures AND
# tabular representations for each GENRE (visualize the standard deviation and
# mean values of all tracks of a genre). Exemplary, select 3 audio tracks and
# describe their similarity both by your personal perception and the
# corresponding feature vectors. Back up why these audio files / feature vectors
# are in fact similar or not. Build mean- and standard-deviation vectors for each
#     genre (<b>THRILLER, DANCE, DOCUMENTARY</b>). (<i>3 x m</i>, where <i>m</i> indicates the number of features)</p>
#
# <b>You should turn in:</b> figures/tables per genre, figures/tables per
# feature (protocol); mean- and standard-deviation-vectors (protocol)<br><p></p>
# <p></p>
# <hr>

# %% [markdown]
# <p><b>You should
# provide:</b>
# <ul>
# <li>function that extracts and displays complete list of feature vectors over all files in the DevSet; we recommend a pandas dataframe to conveniently gather and display the feature data </li>
# <li>how many (at least 5) and what kind of features you choose is up to you. try to find meaningful ones, especially in regards to task 4</li>
# <li>provide the <b>mean</b> and <b>standard deviation</b> over all features per genre. is there any correlation between feature and movie genre? </li>
# <li>provide plots of all features. how do these features behave over all files?</li>
# <li>display all of the specified dataframes and plots on function call <b>processAndDisplayAudioDirectoryFeatures(...)</b>, as shown above</li>
# <li>protocol: answer the given questions and use your results to support your answers</li>
# </ul>
# As guidance, this is an example of how your dataframes and plots should (roughly) look like:

# %% [markdown]
# <table>
#  <thead>
#    <tr style=\text-align: right;\>
#      <th>GENRE STANDARD DEVIATION MATRIX</th>
#      <th>Centroid Means Std</th>
#      <th>Centroid Stds Std</th>
#      <th>Roll-off means Std</th>
#      <th>Roll-off Stds Std</th>
#      <th>Tempos Std</th>
#      <th>Zero Crossing Means Std</th>
#      <th>Zero Crossing Stds Std</th>
#      <th>Energy Means Std</th>
#      <th>Energy Stds Std</th>
#      <th>Flux Means Std</th>
#      <th>Flux Stds Std</th>
#    </tr>
#  </thead>
#  <tbody>
#    <tr>
#      <td>THRILLER</td>
#      <td>155.834379</td>
#      <td>172.607581</td>
#      <td>411.584574</td>
#      <td>44.136524</td>
#      <td>9.602418</td>
#      <td>0.056122</td>
#      <td>0.039366</td>
#      <td>3.207597</td>
#      <td>2.163030</td>
#      <td>1.250348</td>
#      <td>0.328758</td>
#    </tr>
#    <tr>
#      <td>DANCE</td>
#      <td>241.021206</td>
#      <td>111.064897</td>
#      <td>311.170248</td>
#      <td>112.010142</td>
#      <td>11.359136</td>
#      <td>0.043601</td>
#      <td>0.032152</td>
#      <td>1.967691</td>
#      <td>4.963002</td>
#      <td>0.255638</td>
#      <td>0.520323</td>
#    </tr>
#    <tr>
#      <td>DOCUMENTARY</td>
#      <td>157.483844</td>
#      <td>35.022452</td>
#      <td>263.260253</td>
#      <td>151.513420</td>
#      <td>15.648301</td>
#      <td>0.037372</td>
#      <td>0.017317</td>
#      <td>0.254027</td>
#      <td>0.123690</td>
#      <td>0.112475</td>
#      <td>0.299986</td>
#    </tr>
#  </tbody>
# </table>

# %% [markdown]
# <b>Energy standard deviation over all files:</b>
# ![title](imgs/plot_example.png)

# %%
# %run "../Task2&3/Implementation.ipynb"


#build feature matrix from audio directory (like task2)
#not all features this time, only the ones that work well
feature_matrix, file_names = calcFeatureMatrixForDirectory("videos/processed", full=False)

#create similarity matrix, compare every file with every other file
sim_matrix = createSimMatrix(feature_matrix)

#rank similarity of the audio files based on their features (top 5 and top 10 similarities are calculated)
#plot are again saved to "plots" directory
rank_matrix = rankSimMatrix(sim_matrix, plot=True)

#create dataframe for better visualization
dataframe = pd.DataFrame({'Precision Nearest 5': rank_matrix[:, 0], 'Recall Nearest 5': rank_matrix[:, 1],
                          'F Measure Nearest 5': rank_matrix[:, 2], 'Precision Nearest 10': rank_matrix[:, 3],
                          'Recall Nearest 10': rank_matrix[:, 4], 'F Measure Nearest 10': rank_matrix[:, 5]})
dataframe.index = file_names

print(dataframe.to_string())
